# %% [markdown]
# # Lemmatization

# %% [markdown]
# # Wordnet Lemmatizer
# This technique is similar to stemming. The output we will get after lemmatization is called 'lemma', which is a root word rather than root stem. After lemmatization, we will be getting a valid word that means the same thing.
#
# It is a thin wrapper around a WordNet Coupus.
#
# Uses: Q&A, chatbots, text summarization

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to /home/prashant/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/prashant/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize('goes')
# Out:
# 'go'

# %%
'''
POS- Noun - n
     Verb - v
     adjective - a
     adverb - r

'''
lemmatizer.lemmatize('eating', pos= 'v')
# Out:
# 'eat'

# %%
words = ['eating', 'eats', 'eaten', 'writing', 'writes', 'programming', 'programs', 'histroy', "There's"]

# %%
for word in words:
    print (word + ' ---> ' + lemmatizer.lemmatize(word, pos = 'v'))
# Out:
# eating ---> eat
# eats ---> eat
# eaten ---> eat
# writing ---> write
# writes ---> write
# programming ---> program
# programs ---> program
# histroy ---> histroy
# There's ---> There's

# %%
lemmatizer.lemmatize('sportingly', pos= 'a')
# Out:
# 'sportingly'
