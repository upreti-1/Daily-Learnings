# %% [markdown]
# # K Nearest Neighbour Classifeir

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import make_classification

X, y = make_classification(
    n_samples= 1000, 
    n_features= 3,
    n_redundant = 1,
    n_classes= 2,
    random_state= 12
)

# %%
X
# Out:
# array([[-1.52644726, -1.4953745 , -0.63122886],
#        [-1.62781746, -2.85407909, -1.14575126],
#        [-3.08007404,  0.6188504 ,  0.09083664],
#        ...,
#        [-0.61537686, -1.0073314 , -0.40626171],
#        [ 1.62077464,  0.71634373,  0.34321914],
#        [-0.68129288, -0.34488905, -0.16069884]], shape=(1000, 3))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.3, random_state= 42)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors= 5, algorithm= 'auto')
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.88
# [[137  16]
#  [ 20 127]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       153
#            1       0.89      0.86      0.88       147
#
#     accuracy                           0.88       300
#    macro avg       0.88      0.88      0.88       300
# weighted avg       0.88      0.88      0.88       300

# %%
# Hyperparameter tuning using GridSearchCV
from sklearn.model_selection import GridSearchCV

param_grid = {
    'n_neighbors': [3,5,7,9,11,15],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

grid = GridSearchCV(knn, param_grid= param_grid, scoring= 'accuracy')

# %%
grid.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(metric='manhattan', n_neighbors=11,
#                                             p=1, weights='distance'),
#              param_grid={'metric': ['euclidean', 'manhattan', 'minkowski'],
#                          'n_neighbors': [3, 5, 7, 9, 11, 15],
#                          'weights': ['uniform', 'distance']},
#              scoring='accuracy')

# %%
y_pred = grid.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
print(accuracy_score(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.8766666666666667
# [[136  17]
#  [ 20 127]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.89      0.88       153
#            1       0.88      0.86      0.87       147
#
#     accuracy                           0.88       300
#    macro avg       0.88      0.88      0.88       300
# weighted avg       0.88      0.88      0.88       300
